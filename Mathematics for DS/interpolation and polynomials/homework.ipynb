# %% [markdown]
# #1
# # Block 1.
#
# Use symPy to find the polynomials that describe the given sets of points. Then conduct a complete study of each resulting polynomial: check the even / odd, find zeros, intervals of constancy. Plot their graphs. By changing the gap for x, ensure that all zeros are displayed on the graph of the function
#  <br><br><br>
# а) $(-4; -4268), (-3; -1227), (-1; -17), (1; 17), (3; 1227), (4; 4268)$<br><br>
# б)$ (-4; -16729), (-3; -3999), (-1; 5), (1; 1), (3; 4005), (4; 16735)$

# %%
from sympy import *
from sympy.plotting import plot
from sympy.solvers.inequalities import solve_univariate_inequality

init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a0, a1, a2, a3, a4, a5 = symbols('a0, a1, a2, a3, a4, a5')

# %%
eq1 = (-4)**5 * a5 + (-4)**4 * a4 + (-4)**3 * a3 + (-4)**2 * a2 + (-4) * a1 + a0 + 4268
eq2 = (-3)**5 * a5 + (-3)**4 * a4 + (-3)**3 * a3 + (-3)**2 * a2 + (-3) * a1 + a0 + 1227
eq3 = (-1)**5 * a5 + (-1)**4 * a4 + (-1)**3 * a3 + (-1)**2 * a2 + (-1) * a1 + a0 + 17
eq4 = (1)**5 * a5 + (1)**4 * a4 + (1)**3 * a3 + (1)**2 * a2 + (1) * a1 + a0 - 17
eq5 = (3)**5 * a5 + (3)**4 * a4 + (3)**3 * a3 + (3)**2 * a2 + (3) * a1 + a0 - 1227
eq6 = (4)**5 * a5 + (4)**4 * a4 + (4)**3 * a3 + (4)**2 * a2 + (4) * a1 + a0 - 4268

nonlinsolve([eq1, eq2, eq3, eq4, eq5, eq6], [a0, a1, a2, a3, a4, a5])
# Out:
# {(0, -5, 0, 19, 0, 3)}

# %%
x = Symbol('x')

# %%
f = 3*x**5 + 19*x**3 - 5*x
f.subs(x, 10)
# Out:
# 318950

# %%
f.subs(x, -10)
# Out:
# -318950

# %%
f.subs(x, 0)
# Out:
# 0

# %%
plot(f)

# %%
plot(f, (x, 0, 10))

# %%
solve_univariate_inequality(f<0, x)
# Out:
#   /   /                   ________________\     /                ________________\\
#   |   |                  /          _____ |     |               /          _____ ||
#   |   |                 /    19   \/ 421  |     |              /    19   \/ 421  ||
# Or|And|-oo < x, x < -  /   - -- + ------- |, And|0 < x, x <   /   - -- + ------- ||
#   \   \              \/      6       6    /     \           \/      6       6    //

# %% [markdown]
# #2
# ### Get an MSE value less than 5.

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-2, -1, 0, 1, 2, 3, 3.5, 4, 4.5, 5])
    points_Y = np.array([2, -4, 1, 8, 21, 40, 47, 65, 75, 92])
    plt.xlim(-6, 10)
    plt.ylim(-1, 100)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

# %%
f1 = 48 * x**2 - 128 * x + 83
f1
# Out:
#     2
# 48*x  - 128*x + 83

# %%
f1_1 = f1.subs(x, x+1.5)

# %%
f1_2 = f1_1.subs(x, 0.25*x)

# %%
print_points_ands_function1(f1_2)
# Out:
# MSE = 4.412499999999996

# %%
def print_points_ands_function2(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-2, -1, 0, 1, 2, 3, 3.5, 4, 4.5, 5])
    points_Y = np.array([-31, -9, 4, -1, 9, 24, 47, 92, 120, 170])
    plt.xlim(-3, 6)
    plt.ylim(-35, 200)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

# %%
f2 = 4 * x**3 + 30 * x**2 + 74 * x + 62
f2
# Out:
#    3       2
# 4*x  + 30*x  + 74*x + 62

# %%
f2_1 = f2.subs(x, x - 3)

# %%
f2_2 = f2_1.subs(x, 0.8*x)

# %%
print_points_ands_function2(f2_2)
# Out:
# MSE = 24.893216
