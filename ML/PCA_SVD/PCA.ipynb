# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib inline
df_source = pd.read_csv('client_segmentation.csv')
X = df_source[['call_diff','sms_diff','traffic_diff']].values
y = df_source.customes_class.values
print(df_source)
# Out:
#     call_diff  sms_diff  traffic_diff  customes_class
# 0   -0.666421  0.444911     -0.273538             0.0
# 1   -0.889273 -0.537896     -1.959469             2.0
# 2   -0.841503  0.846665      0.727606             0.0
# 3    1.389749  0.390911      1.789246             1.0
# 4   -1.228211 -1.375899     -1.434209             2.0
# ..        ...       ...           ...             ...
# 95   1.506425 -0.483638      2.096115             1.0
# 96  -1.948987 -2.192459      0.943793             2.0
# 97  -1.384253  1.522339      2.854824             0.0
# 98   1.957208  0.429976      2.750221             1.0
# 99  -1.612803  1.696377     -1.020921             0.0
#
# [100 rows x 4 columns]

# %%
plt.scatter(df_source.call_diff, df_source.traffic_diff, c = y)

# %%
from sklearn.decomposition import PCA

# %%
pca_model = PCA(n_components=1).fit(df_source[['call_diff', 'traffic_diff']])
X_pca = pca_model.transform(df_source[['call_diff', 'traffic_diff']])
type(X_pca)
# Out:
# numpy.ndarray

# %%
X_new = pca_model.inverse_transform(X_pca)
X_new
# Out:
# array([[-0.61054353, -0.30256376],
#        [-1.34756698, -1.72140577],
#        [-0.23820663,  0.41422107],
#        [ 0.67021075,  2.16301312],
#        [-1.20471983, -1.44641109],
#        [ 0.1723787 ,  1.20463788],
#        [ 0.55063935,  1.93282651],
#        [-1.06129401, -1.17030239],
#        [-1.26980017, -1.57169709],
#        [ 0.47842386,  1.79380465],
#        [ 0.04415487,  0.9577945 ],
#        [-0.38503728,  0.13155776],
#        [ 0.22844391,  1.31256886],
#        [ 1.34871865,  3.46920698],
#        [-0.53118693, -0.14979457],
#        [-0.96764373, -0.99001647],
#        [ 0.54622183,  1.92432235],
#        [ 0.32818682,  1.5045837 ],
#        [-0.62351835, -0.32754156],
#        [ 0.99130808,  2.78115678],
#        [-0.07292007,  0.73241382],
#        [ 0.23685863,  1.32876802],
#        [-0.98634616, -1.02602048],
#        [ 0.79203239,  2.39753164],
#        [ 1.07208258,  2.93665557],
#        [ 0.63580483,  2.09677836],
#        [-1.56712784, -2.14408184],
#        [-0.69852668, -0.47193991],
#        [-0.2633796 ,  0.36576065],
#        [-1.57647238, -2.16207099],
#        [-0.64242332, -0.36393547],
#        [ 0.58130781,  1.99186629],
#        [-0.20030982,  0.48717613],
#        [-0.18458024,  0.5174571 ],
#        [-0.42721095,  0.05036932],
#        [ 1.55262194,  3.86174069],
#        [ 0.30050892,  1.45130104],
#        [ 0.07253508,  1.01242916],
#        [ 0.13111643,  1.12520399],
#        [-1.00755582, -1.06685113],
#        [-1.00858235, -1.0688273 ],
#        [ 0.17097731,  1.20194007],
#        [ 0.3833603 ,  1.61079803],
#        [-0.16409499,  0.5568932 ],
#        [-1.55053313, -2.11213541],
#        [-0.45969273, -0.01216126],
#        [-0.35308107,  0.19307658],
#        [-0.10458404,  0.6714576 ],
#        [-1.3702831 , -1.76513652],
#        [ 0.72307759,  2.26478694],
#        [ 0.24454748,  1.34356982],
#        [-0.18995546,  0.50710929],
#        [-0.25007954,  0.39136457],
#        [ 0.44080028,  1.72137558],
#        [ 0.51547418,  1.86513012],
#        [-0.98001538, -1.0138331 ],
#        [-0.61163279, -0.30466069],
#        [-1.49694939, -2.00898147],
#        [-0.08704944,  0.7052134 ],
#        [ 0.44361854,  1.72680102],
#        [ 0.69006785,  2.20123997],
#        [ 0.05514709,  0.97895558],
#        [-0.43964399,  0.02643451],
#        [-0.70911575, -0.49232489],
#        [ 0.47695875,  1.79098416],
#        [-1.09703666, -1.23911047],
#        [ 0.39013393,  1.62383793],
#        [-1.22826145, -1.49173099],
#        [-0.24500419,  0.40113512],
#        [-1.24545606, -1.52483229],
#        [ 0.03198933,  0.93437465],
#        [ 0.49334235,  1.8225242 ],
#        [-0.94987865, -0.95581696],
#        [-1.44361022, -1.90629838],
#        [-0.3336157 ,  0.23054931],
#        [-0.75134745, -0.57362504],
#        [-0.90555231, -0.87048443],
#        [ 0.74047059,  2.29827015],
#        [-0.6255671 , -0.3314856 ],
#        [-0.05262182,  0.77148993],
#        [ 0.86766143,  2.54312492],
#        [-1.59682371, -2.20124927],
#        [ 0.73433011,  2.28644913],
#        [ 1.06055899,  2.91447153],
#        [-1.14301684, -1.32762682],
#        [-0.16796336,  0.54944621],
#        [-1.00285998, -1.05781118],
#        [-0.8324691 , -0.72979213],
#        [ 1.00732561,  2.81199209],
#        [-1.08901264, -1.22366346],
#        [-0.86507056, -0.79255311],
#        [-0.75176092, -0.57442101],
#        [ 0.54048457,  1.91327756],
#        [-1.05851485, -1.16495224],
#        [ 0.03293477,  0.93619471],
#        [ 0.82053579,  2.45240346],
#        [-0.38510483,  0.13142772],
#        [ 0.51664939,  1.86739251],
#        [ 1.18390158,  3.15191805],
#        [-1.11737881, -1.27827109]])

# %%
plt.scatter(X_new[:, 0], X_new[:, 1])

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
# %matplotlib inline

fig = plt.figure(1, figsize=(6, 5))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134); plt.cla()
num_labels = np.unique(y).size
for name, label in [('class_%d' % i, i) for i in range(num_labels)]:
    ax.text3D(X[y == label, 0].mean(), X[y == label, 1].mean() + 0.5,
        X[y == label, 2].mean(), name, horizontalalignment='center',
        bbox=dict(alpha=.5, edgecolor='w', facecolor='w'))
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y)
ax.w_xaxis.set_ticklabels([]); ax.w_yaxis.set_ticklabels([]); ax.w_zaxis.set_ticklabels([])
plt.show()

# %%
pca_model1 = PCA(n_components=2).fit(X)
X_pca1 = pca_model1.transform(X)
X_new1 = pca_model1.inverse_transform(X_pca1)
X_pca1
# Out:
# array([[-7.57445169e-01, -1.66230765e-01],
#        [-2.61154618e+00, -5.95169201e-01],
#        [ 1.33013456e-01,  3.73835973e-01],
#        [ 1.74983161e+00, -2.75824330e-01],
#        [-2.69734129e+00,  3.16244631e-01],
#        [ 7.08605332e-01,  5.15471706e-01],
#        [ 1.27113452e+00, -4.82206892e-02],
#        [-2.51547698e+00, -2.30086666e-01],
#        [ 2.16121134e-01,  3.41091246e-01],
#        [ 1.84178181e+00,  6.83971398e-01],
#        [-9.83238175e-01, -1.48180927e+00],
#        [-2.68922070e+00, -1.21117515e+00],
#        [ 2.16954385e-01,  1.55212536e+00],
#        [-8.18976607e-01,  6.62586056e-01],
#        [-1.57159929e+00, -9.51952788e-01],
#        [ 2.77491137e+00, -1.32511797e+00],
#        [-3.46113663e-01, -1.35214495e+00],
#        [ 4.20588409e-01, -6.96989761e-01],
#        [ 2.83101565e+00, -1.01108667e+00],
#        [-2.58228637e+00, -2.52694336e+00],
#        [ 2.30876992e+00, -7.88792499e-01],
#        [ 2.61023764e+00, -2.55611405e-01],
#        [-1.97303744e+00, -1.27060719e+00],
#        [ 2.78603305e-01, -8.43077628e-01],
#        [-1.42215877e+00, -1.00974441e+00],
#        [-1.48092280e+00, -4.00703442e-01],
#        [ 2.17478142e+00,  1.30608435e-01],
#        [-2.50188679e+00,  5.38093803e-01],
#        [-1.75215042e+00,  2.00002262e-01],
#        [-7.52663705e-01,  4.20781491e-01],
#        [ 1.07405849e+00,  1.66828771e-01],
#        [-2.23810505e+00,  2.47001021e-01],
#        [ 1.04441047e+00,  8.19308872e-02],
#        [ 1.67241749e+00,  2.16825686e-01],
#        [-1.46728136e+00,  2.58463892e+00],
#        [ 1.87538907e+00,  1.71384442e+00],
#        [ 2.77597578e+00, -9.48619223e-02],
#        [-1.22940156e+00, -5.36379545e-01]])

# %%
plt.scatter(X_pca1[:, 0], X_pca1[:, 1], c=y)

# %%
# 8.6

# %%
import numpy as np
from numpy.linalg import svd, det

# %%
# 1

# %%
A = np.array([[3,2,2],[2,3,-2]])

# %%
u, s, vh = np.linalg.svd(A)
vh
# Out:
# array([[ 7.07106781e-01,  7.07106781e-01,  3.67439059e-16],
#        [-2.35702260e-01,  2.35702260e-01, -9.42809042e-01],
#        [-6.66666667e-01,  6.66666667e-01,  3.33333333e-01]])

# %%
U_det = np.linalg.det(u)
U_det
# Out:
# 0.9999999999999997

# %%
from matplotlib.pyplot import imshow
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
# 2

# %%
img = mpimg.imread('8.6/dorian_grey.png')
print(type(img),img.shape)
imshow(img)
plt.show()
# Out:
# <class 'numpy.ndarray'> (380, 509, 3)

# %%
def rgb2gray(rgb):
#   ''' Берётся среднее трёх цветов RGB'''
    tile = np.tile(np.c_[0.333, 0.333, 0.333], reps=(rgb.shape[0],rgb.shape[1],1))
    return np.sum(tile * rgb, axis=2)

img_gray = rgb2gray(img)
print(type(img_gray), img_gray.shape)
imshow(img_gray, cmap = "gray")
plt.show()
# Out:
# <class 'numpy.ndarray'> (380, 509)

# %%
from sklearn.decomposition import TruncatedSVD

# %%
svd_model = TruncatedSVD(n_components=5).fit(img_gray)
img_gray_svd = svd_model.transform(img_gray)
img_gray_svd_restored = svd_model.inverse_transform(img_gray_svd)

# %%
imshow(img_gray_svd_restored, cmap = "gray")
